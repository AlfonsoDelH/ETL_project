# %% [markdown]
# ## Import dependencies

# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup as bs
import requests

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## List of all languages I want to look for

# %%
language=["python", "sql", "mongodb", "javascript"]

# %% [markdown]
# ## Create empty list for all the information wanted

# %%
job_title=[]
job_description=[]
salaries=[]
languages=[]

# %% [markdown]
# ## Loop for languages wanted in order to get the proper url and then visit the website

# %%
for lan in language:
    language_url='https://www.occ.com.mx/empleos/de-'+ lan + '/en-ciudad-de-mexico/'
    browser.visit(language_url)
    response=requests.get(language_url)
    soup=bs(response.text,'html.parser')
    listings=soup.find('div', class_='c0132 c0177 c01465')

    #Iterate trough all listings in the website and extract the information wanted
    
    for l in listings:
        jt=l.find_all('h2', class_='c01415 c01417 c01533')
        for j in jt:
            j_t=j.text
            job_title.append(j_t)

       
        #Append a "NaN" for all listings that do not mention the salary
        
        pre_salary=l.find_all('div', class_="c01409")
        for p in pre_salary:
            if p.find_all('span', id="salaryInfo")==[]:
                salaries.append("NaN")
            else:
                salary=p.find_all('span', id="salaryInfo")
                for s in salary:
                    sa=s.text.replace('$','').replace(',','')
                    salaries.append(sa)

        jd=l.find_all('p', class_="c01544")
        for i in jd:
            j_d=i.text
            job_description.append(j_d)
            languages.append(lan)
        
    
    #Extract the information for the first 5 pages of each language search

    for x in range(2,6):
        next_url=language_url+'?page='+str(x)
        browser.visit(next_url)
        response=requests.get(next_url)
        soup=bs(response.text,'html.parser')
        listings=soup.find('div', class_='c0132 c0177 c01465')
        
        try:
            
            #In case there were less than 5 pages for each search
            
            for l in listings:
                jt=l.find_all('h2', class_='c01415 c01417 c01533')
                for j in jt:
                    j_t=j.text
                    job_title.append(j_t)

                pre_salary=l.find_all('div', class_="c01409")
                for p in pre_salary:
                    if p.find_all('span', id="salaryInfo")==[]:
                        salaries.append("NaN")
                    else:
                        salary=p.find_all('span', id="salaryInfo")
                        for s in salary:
                            sa=s.text.replace('$','').replace(',','')
                            salaries.append(sa)

                jd=l.find_all('p', class_="c01544")
                for i in jd:
                    j_d=i.text
                    job_description.append(j_d)
                    languages.append(lan)
        except:
            pass

# %% [markdown]
# ## Check if we have an even database

# %%
print(len(job_description))
print(len(salaries))
print(len(job_title))
print(len(languages))
# Out:
# 801
# 801
# 801
# 801

# %% [markdown]
# ## Create a dataframe with the information gathered

# %%
import pandas as pd
occ_data=list(zip(job_title,job_description,salaries,languages))
occ_df=pd.DataFrame(occ_data,columns=["Job title","Job Description","Salary","Languages"])

# %% [markdown]
# ## Add three columns with the maximum, minimun and average salary and drop job description column since it does not add value. Check if dataframe looks good

# %%
occ_df['Min_Salary']=occ_df['Salary'].str.split(' - ')
occ_df['Min_Salary']=occ_df['Min_Salary'].str.get(0).astype(float)

occ_df['Max_Salary']=occ_df['Salary'].str.split(' - ')
occ_df['Max_Salary']=occ_df['Max_Salary'].str.get(1).astype(float)

occ_df['Avg_Salary']=(occ_df['Min_Salary']+occ_df['Max_Salary'])/2

occ_df=occ_df.drop(columns=["Job Description","Salary"])

occ_df
# Out:
#                                              Job title   Languages  \
# 0                                   Programador Python      python
# 1                                 Desarrollador Python      python
# 2      Coordinador de medición de indicadores (Python)      python
# 3                                     Python Tech Lead      python
# 4                                         DATA SCIENCE      python
# 5                                      DevOps Engineer      python
# 6                              Especialista de Pricing      python
# 7                               Desarrollador software      python
# 8                                               Tester      python
# 9                       Technical Security Coordinator      python
# 10                                Analista Estadístico      python
# 11      ARQUITECTO DE SOLUCIONES BIG DATA/DATA LAKE SR      python
# 12                            Scrum Master- Ingles 70%      python
# 13                                   Big Data Engineer      python
# 14                       Desarrollador de sistema ODOO      python
# 15               Documentalista (Portfolio Management)      python
# 16                       Solutions Architect Associate      python
# 17                                QA Automation SSR/SR      python
# 18                                    DevOPs Tech Lead      python
# 19            Python Junior Analyst - Advanced English      python
# 20                                       Data Engineer      python
# 21   Business Intelligence con experiencia en data ...      python
# 22        "URGE Desarrollador Inteligencia Artificial"      python
# 23             Desarrollador Phyton - Nextengo y Toreo      python
# 24            Business Specialist in Data Architecture      python
# 25                                   Consultor Bigdata      python
# 26                                DESARROLLADOR SOA JR      python
# 27   Credit Portf Intmd Analyst - Scoring / Consume...      python
# 28         Consultor Sr en Seguridad de la Información      python
# 29              JAVA JUNIOR ANALYST - ADVANCED ENGLISH      python
# ..                                                 ...         ...
# 771                                 Jefe de desarrollo  javascript
# 772                                  DESARROLLADOR NET  javascript
# 773           Desarrollador JAVA/.NET/ PHP (APIs REST)  javascript
# 774                                   DESARROLLADOR C#  javascript
# 775                               Full Stack Developer  javascript
# 776                                 Desarrollador .NET  javascript
# 777  Desarrollador PHP (Urgente Polanco Por Temporada)  javascript
# 778                        Desarrollador Java FrontEnd  javascript
# 779                                  Desarrollador PHP  javascript
# 780                         Gerente Estrategia Digital  javascript
# 781               Desarrollador FullStack - Permanente  javascript
# 782                            Desarrollador Front End  javascript
# 783            *Gerente de Desarrollo de Aplicaciones*  javascript
# 784                       Programador Java Jr y Senior  javascript
# 785                                     Consultor Java  javascript
# 786                      Web UI Lead (California, EUA)  javascript
# 787   LIDER DE PROYECTO/ DESARROLLO DE SISTEMAS (CDMX)  javascript
# 788                              Diseñador gráfico web  javascript
# 789                          DESARROLLADOR APIs JUNIOR  javascript
# 790                                     APIs DEVELOPER  javascript
# 791                                 DESARROLLADOR APIs  javascript
# 792                                 Desarrollador Java  javascript
# 793                        Soporte de Aplicaciones Jr.  javascript
# 794  Desarrrollador Java (Front End) y (Back End)- ...  javascript
# 795                 Desarrollador Front-end y Back-end  javascript
# 796  Desarrollador Intermedio .NET framework 4.5 (U...  javascript
# 797                              Tester Automatización  javascript
# 798                             Arquitecto de Software  javascript
# 799               Desarrollador Full Stack J2EE /Cloud  javascript
# 800                              Desarrollador .NET C#  javascript
#
#      Min_Salary  Max_Salary  Avg_Salary
# 0       12000.0     17000.0     14500.0
# 1       20000.0     25000.0     22500.0
# 2       22000.0     30000.0     26000.0
# 3           NaN         NaN         NaN
# 4       32000.0     35000.0     33500.0
# 5       50000.0     60000.0     55000.0
# 6           NaN         NaN         NaN
# 7       30000.0         NaN         NaN
# 8           NaN         NaN         NaN
# 9       20000.0     30000.0     25000.0
# 10      13000.0     15000.0     14000.0
# 11          NaN         NaN         NaN
# 12      17000.0     25000.0     21000.0
# 13          NaN         NaN         NaN
# 14          NaN         NaN         NaN
# 15      40000.0         NaN         NaN
# 16          NaN         NaN         NaN
# 17       3000.0         NaN         NaN
# 18       3000.0         NaN         NaN
# 19      18000.0     27000.0     22500.0
# 20      17000.0     22000.0     19500.0
# 21          NaN         NaN         NaN
# 22      22000.0     24000.0     23000.0
# 23          NaN         NaN         NaN
# 24      26000.0     30000.0     28000.0
# 25          NaN         NaN         NaN
# 26      30000.0     35000.0     32500.0
# 27          NaN         NaN         NaN
# 28      40000.0     50000.0     45000.0
# 29      20000.0     30000.0     25000.0
# ..          ...         ...         ...
# 771         NaN         NaN         NaN
# 772     29000.0         NaN         NaN
# 773     25000.0     30000.0     27500.0
# 774     29000.0         NaN         NaN
# 775     30000.0     35000.0     32500.0
# 776     18000.0     24000.0     21000.0
# 777     19000.0     22000.0     20500.0
# 778         NaN         NaN         NaN
# 779     33000.0     37000.0     35000.0
# 780         NaN         NaN         NaN
# 781     30000.0     40000.0     35000.0
# 782     20000.0     28000.0     24000.0
# 783         NaN         NaN         NaN
# 784     18000.0     28000.0     23000.0
# 785     30000.0     35000.0     32500.0
# 786         NaN         NaN         NaN
# 787         NaN         NaN         NaN
# 788         NaN         NaN         NaN
# 789     30000.0         NaN         NaN
# 790     35000.0         NaN         NaN
# 791     30000.0         NaN         NaN
# 792     28000.0     30000.0     29000.0
# 793      8000.0     10000.0      9000.0
# 794     27000.0     35000.0     31000.0
# 795     17000.0     18000.0     17500.0
# 796     20000.0     25000.0     22500.0
# 797     50000.0     60000.0     55000.0
# 798     45000.0     50000.0     47500.0
# 799         NaN         NaN         NaN
# 800     15000.0     25000.0     20000.0
#
# [801 rows x 5 columns]

# %% [markdown]
# ## Connect to local database

# %%
from sqlalchemy import create_engine
connection_string = "postgres:postgres@localhost:5432/jobs_scrap_data"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ## Check for the tables

# %%
engine.table_names()
# Out:
# ['jobs_data']

# %% [markdown]
# ## Load DataFrame into database

# %%
occ_df.to_sql(name='jobs_data', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## Check if the dataframe was uploaded successfully

# %%
pd.read_sql_query('select * from jobs_data', con=engine).head()
# Out:
#    id                                        Job title Languages  Min_Salary  \
# 0   1                               Programador Python    python     12000.0
# 1   2                             Desarrollador Python    python     20000.0
# 2   3  Coordinador de medición de indicadores (Python)    python     22000.0
# 3   4                                 Python Tech Lead    python         NaN
# 4   5                                     DATA SCIENCE    python     32000.0
#
#    Max_Salary  Avg_Salary
# 0     17000.0     14500.0
# 1     25000.0     22500.0
# 2     30000.0     26000.0
# 3         NaN         NaN
# 4     35000.0     33500.0
